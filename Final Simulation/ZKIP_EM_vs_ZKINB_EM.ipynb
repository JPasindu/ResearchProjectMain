# %%
from ZKIP_EM import ZKIP_EM
from ZKINB_EM import ZKINB_EM
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [8], line 2
#       1 from ZKIP_EM import ZKIP_EM
# ----> 2 from ZKINB_EM import ZKINB_EM
#
# ImportError: cannot import name 'ZKINB_EM' from 'ZKINB_EM' (/Users/pasindumadusanka/Documents/GitHub/ResearchProject/ResearchProjectMain/Final Simulation/ZKINB_EM.py)

# %%
model = ZkINB_EM()
res = model.fit_em(y_train, X_train.reshape(-1, 1), X_train.reshape(-1, 1), k)
y_pred_inb=model.predict(X_test.reshape(-1, 1), X_test.reshape(-1, 1))
mse = mean_squared_error(y_test, y_pred_inb)
mae = mean_absolute_error(y_test, y_pred_inb) 
r_2 = r2_score(y_test, y_pred_inb)  
mse, mae, r_2

# %%
from models.ZKIP_EM import *
